# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('Webcam', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
image = cv2.cvtColor(cv2.imread(r"C:\Users\heath\Downloads\Archery pictures\Blank Face.jpeg"), cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.grid()

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.grid(color='gray', linestyle='--', linewidth=1)
plt.show()
